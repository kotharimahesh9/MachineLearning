# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ### Use Linear Regression Model to compare the results with the Polynomial Regressor

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()
linear_regressor.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Use Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 2)
X_poly = poly_reg.fit_transform(X)
print(X_poly)

linear_regressor_2 = LinearRegression()
linear_regressor_2.fit(X_poly, y)
# Out:
# [[  1.   1.   1.]
#  [  1.   2.   4.]
#  [  1.   3.   9.]
#  [  1.   4.  16.]
#  [  1.   5.  25.]
#  [  1.   6.  36.]
#  [  1.   7.  49.]
#  [  1.   8.  64.]
#  [  1.   9.  81.]
#  [  1.  10. 100.]]
# LinearRegression()

# %% [markdown]
# ## Visualize the data

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, linear_regressor.predict(X), color = 'blue')
plt.plot(X, linear_regressor_2.predict(X_poly), color = 'green')
plt.xlabel('Position')
plt.ylabel('Salary')
plt.show()

# %%
poly_reg_3 = PolynomialFeatures(degree = 4)
X_poly_3 = poly_reg_3.fit_transform(X)
linear_regressor_3 = LinearRegression()
linear_regressor_3.fit(X_poly_3, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, linear_regressor.predict(X), color = 'blue')
plt.plot(X, linear_regressor_3.predict(X_poly_3), color = 'green')
plt.xlabel('Position')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ### Predict the salary at Level 6.5 using both Linear Regression and Polynomial Regression

# %%
linear_regressor.predict([[6.5]])
# Out:
# array([330378.78787879])

# %%
linear_regressor_3.predict(poly_reg_3.transform([[6.5]]))
# Out:
# array([158862.45265153])
